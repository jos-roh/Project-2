# %%
import pandas as pd

# %%
df=pd.read_csv('Online Retail (3).xlsx - Online Retail.csv'
)

# %%
print(df.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
print(df.tail())
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/11 12:50       0.85     12680.0  France
# 541905  12/9/11 12:50       2.10     12680.0  France
# 541906  12/9/11 12:50       4.15     12680.0  France
# 541907  12/9/11 12:50       4.15     12680.0  France
# 541908  12/9/11 12:50       4.95     12680.0  France

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/11 12:50       0.85     12680.0  France
# 541905  12/9/11 12:50       2.10     12680.0  France
# 541906  12/9/11 12:50       4.15     12680.0  France
# 541907  12/9/11 12:50       4.15     12680.0  France
# 541908  12/9/11 12:50       4.95     12680.0  France

# %%
#checking the shape of data

# %%
df.shape
# Out:
# (541909, 8)

# %%
#checking the info of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# We understand that there are null values in Description and CustomerID.

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#Going through the respective columns step by step

# %%
df["InvoiceNo"]
# Out:
# 0         536365
# 1         536365
# 2         536365
# 3         536365
# 4         536365
#            ...
# 541904    581587
# 541905    581587
# 541906    581587
# 541907    581587
# 541908    581587
# Name: InvoiceNo, Length: 541909, dtype: object

# %%
df["StockCode"]
# Out:
# 0         85123A
# 1          71053
# 2         84406B
# 3         84029G
# 4         84029E
#            ...
# 541904     22613
# 541905     22899
# 541906     23254
# 541907     23255
# 541908     22138
# Name: StockCode, Length: 541909, dtype: object

# %%
df["Description"]
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: Description, Length: 541909, dtype: object

# %%
df["Quantity"]
# Out:
# 0          6
# 1          6
# 2          8
# 3          6
# 4          6
#           ..
# 541904    12
# 541905     6
# 541906     4
# 541907     4
# 541908     3
# Name: Quantity, Length: 541909, dtype: int64

# %%
df["InvoiceDate"]
# Out:
# 0          12/1/10 8:26
# 1          12/1/10 8:26
# 2          12/1/10 8:26
# 3          12/1/10 8:26
# 4          12/1/10 8:26
#               ...
# 541904    12/9/11 12:50
# 541905    12/9/11 12:50
# 541906    12/9/11 12:50
# 541907    12/9/11 12:50
# 541908    12/9/11 12:50
# Name: InvoiceDate, Length: 541909, dtype: object

# %%
df["UnitPrice"]
# Out:
# 0         2.55
# 1         3.39
# 2         2.75
# 3         3.39
# 4         3.39
#           ...
# 541904    0.85
# 541905    2.10
# 541906    4.15
# 541907    4.15
# 541908    4.95
# Name: UnitPrice, Length: 541909, dtype: float64

# %%
df["CustomerID"]
# Out:
# 0         17850.0
# 1         17850.0
# 2         17850.0
# 3         17850.0
# 4         17850.0
#            ...
# 541904    12680.0
# 541905    12680.0
# 541906    12680.0
# 541907    12680.0
# 541908    12680.0
# Name: CustomerID, Length: 541909, dtype: float64

# %%
df["Country"]
# Out:
# 0         United Kingdom
# 1         United Kingdom
# 2         United Kingdom
# 3         United Kingdom
# 4         United Kingdom
#                ...
# 541904            France
# 541905            France
# 541906            France
# 541907            France
# 541908            France
# Name: Country, Length: 541909, dtype: object

# %%
df["InvoiceNo"].unique()
# Out:
# array(['536365', '536366', '536367', ..., '581585', '581586', '581587'],
#       dtype=object)

# %%
df["InvoiceNo"].head()
# Out:
# 0    536365
# 1    536365
# 2    536365
# 3    536365
# 4    536365
# Name: InvoiceNo, dtype: object

# %%
df["InvoiceNo"].head(50)
# Out:
# 0     536365
# 1     536365
# 2     536365
# 3     536365
# 4     536365
# 5     536365
# 6     536365
# 7     536366
# 8     536366
# 9     536367
# 10    536367
# 11    536367
# 12    536367
# 13    536367
# 14    536367
# 15    536367
# 16    536367
# 17    536367
# 18    536367
# 19    536367
# 20    536367
# 21    536368
# 22    536368
# 23    536368
# 24    536368
# 25    536369
# 26    536370
# 27    536370
# 28    536370
# 29    536370
# 30    536370
# 31    536370
# 32    536370
# 33    536370
# 34    536370
# 35    536370
# 36    536370
# 37    536370
# 38    536370
# 39    536370
# 40    536370
# 41    536370
# 42    536370
# 43    536370
# 44    536370
# 45    536370
# 46    536371
# 47    536372
# 48    536372
# 49    536373
# Name: InvoiceNo, dtype: object

# %%
df.loc[141:]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 141      C536379         D                           Discount        -1
# 142       536382     10002        INFLATABLE POLITICAL GLOBE         12
# 143       536382     21912           VINTAGE SNAKES & LADDERS         8
# 144       536382     21832               CHOCOLATE CALCULATOR        12
# 145       536382     22411  JUMBO SHOPPER VINTAGE RED PAISLEY        10
# ...          ...       ...                                ...       ...
# 541904    581587     22613        PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899       CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254      CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255    CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138      BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
len(df["InvoiceNo"].unique())
# Out:
# 25900

# %%
df.loc[141:200]
# Out:
#     InvoiceNo StockCode                          Description  Quantity  \
# 141   C536379         D                             Discount        -1
# 142    536382     10002          INFLATABLE POLITICAL GLOBE         12
# 143    536382     21912             VINTAGE SNAKES & LADDERS         8
# 144    536382     21832                 CHOCOLATE CALCULATOR        12
# 145    536382     22411    JUMBO SHOPPER VINTAGE RED PAISLEY        10
# 146    536382     22379             RECYCLING BAG RETROSPOT         10
# 147    536382     22381               TOY TIDY PINK POLKADOT        50
# 148    536382     22798     ANTIQUE GLASS DRESSING TABLE POT         8
# 149    536382     22726           ALARM CLOCK BAKELIKE GREEN         4
# 150    536382     22926       IVORY GIANT GARDEN THERMOMETER        12
# 151    536382     22839      3 TIER CAKE TIN GREEN AND CREAM         2
# 152    536382     22838        3 TIER CAKE TIN RED AND CREAM         2
# ...

# %%
df.sample(13)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 483320    577500     84006            MAGIC TREE -PAPER FLOWERS         1
# 245554    558614     23291             DOLLY GIRL CHILDRENS CUP         4
# 475587    576905     22568                FELTCRAFT CUSHION OWL         4
# 213665    555551    79030D                      TUMBLER BAROQUE        24
# 184146    552676    85123a   WHITE HANGING HEART T-LIGHT HOLDER         2
# 308170    563940     20728                  LUNCH BAG CARS BLUE        10
# 104644    545188     10133         COLOURING PENCILS BROWN TUBE         3
# 28065     538625     21671         RED SPOT CERAMIC DRAWER KNOB        12
# 175478    551960     22621           TRADITIONAL KNITTING NANCY        12
# 495248    578293     23307  SET OF 60 PANTRY DESIGN CAKE CASES         24
# 255876    559372     22758     LARGE PURPLE BABUSHKA NOTEBOOK          12
# 262769    559923    90198A  VINTAGE ROSE BEAD BRACELET RASPBERR         1
# ...

# %%
df.sample(100)
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 144930                                       TRAVEL SEWING KIT         3
# 503433                                  EASTER CRAFT 4 CHICKS          4
# 7188                                                       NaN       -20
# 475111                                      LUNCH BAG WOODLAND        10
# 66536                                        TRAVEL SEWING KIT         2
# ...          ...       ...                                 ...       ...
# 329797                      ROUND SNACK BOXES SET OF 4 FRUITS         12
# 476830                                      BLUE DISCO HANDBAG         4
# 4145                                 TV DINNER TRAY DOLLY GIRL         1
# 252867                                   TEA TIME DES TEA COSY         1
# 478239                                    CAMOUFLAGE LED TORCH         1
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df['StockCode']=df['StockCode'].str.replace(r'[^0-9]','')
# Out:
# C:\Users\JMS\AppData\Local\Temp\ipykernel_11360\1539721638.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['StockCode']=df['StockCode'].str.replace(r'[^0-9]','')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.head(100)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
# ..       ...       ...                                  ...       ...
# 95    536378     22352    LUNCH BOX WITH CUTLERY RETROSPOT          6
# 96    536378     21212      PACK OF 72 RETROSPOT CAKE CASES       120
# 97    536378     21975       PACK OF 60 DINOSAUR CAKE CASES        24
# 98    536378     21977   PACK OF 60 PINK PAISLEY CAKE CASES        24
# 99    536378     84991          60 TEATIME FAIRY CAKE CASES        24
#
#      InvoiceDate  UnitPrice  CustomerID         Country
# 0   12/1/10 8:26       2.55     17850.0  United Kingdom
# ...

# %%
df['InvoiceDate']=df['InvoiceDate'].str.replace(r'\b\d{1,2}:\d{2}(:\d{2})?\b','')
# Out:
# C:\Users\JMS\AppData\Local\Temp\ipykernel_11360\4162677586.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['InvoiceDate']=df['InvoiceDate'].str.replace(r'\b\d{1,2}:\d{2}(:\d{2})?\b','')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.head(144)
# Out:
#     InvoiceNo StockCode                          Description  Quantity  \
# 0      536365     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365     71053                  WHITE METAL LANTERN         6
# 2      536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
# ..        ...       ...                                  ...       ...
# 139    536381     22719         GUMBALL MONOCHROME COAT RACK        36
# 140    536381     21523   DOORMAT FANCY FONT HOME SWEET HOME        10
# 141   C536379                                       Discount        -1
# 142    536382     10002          INFLATABLE POLITICAL GLOBE         12
# 143    536382     21912             VINTAGE SNAKES & LADDERS         8
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0      12/1/10        2.55     17850.0  United Kingdom
# ...

# %%
df['InvoiceNo']=df['InvoiceNo'].str.replace(r'[^0-9]','')
# Out:
# C:\Users\JMS\AppData\Local\Temp\ipykernel_11360\1387006000.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['InvoiceNo']=df['InvoiceNo'].str.replace(r'[^0-9]','')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.head(142)
# Out:
#     InvoiceNo StockCode                          Description  Quantity  \
# 0      536365     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365     71053                  WHITE METAL LANTERN         6
# 2      536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
# ..        ...       ...                                  ...       ...
# 137    536381     21731        RED TOADSTOOL LED NIGHT LIGHT         2
# 138    536381     22778                   GLASS CLOCHE SMALL         3
# 139    536381     22719         GUMBALL MONOCHROME COAT RACK        36
# 140    536381     21523   DOORMAT FANCY FONT HOME SWEET HOME        10
# 141    536379                                       Discount        -1
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0      12/1/10        2.55     17850.0  United Kingdom
# ...

# %%
df['Quantity']=df['Quantity'].abs()

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[141]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 141
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.head(142)
# Out:
#     InvoiceNo StockCode                          Description  Quantity  \
# 0      536365     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365     71053                  WHITE METAL LANTERN         6
# 2      536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
# ..        ...       ...                                  ...       ...
# 137    536381     21731        RED TOADSTOOL LED NIGHT LIGHT         2
# 138    536381     22778                   GLASS CLOCHE SMALL         3
# 139    536381     22719         GUMBALL MONOCHROME COAT RACK        36
# 140    536381     21523   DOORMAT FANCY FONT HOME SWEET HOME        10
# 141    536379                                       Discount         1
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0      12/1/10        2.55     17850.0  United Kingdom
# ...

# %%
df.to_csv('Output.csv', index=False)
